# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(-10,10,100)

M=float(input("enter val:"))
y1=M*x**2
y2=M*np.sin(x)
plt.figure()
plt.plot(x,y1,label="Y1", color='blue', linestyle='--')
plt.plot(x,y2,label='Y2',color='red',linestyle="-")
plt.legend()
plt.grid(True)
plt.title(f"plots")
plt.show()
# Out:
# enter val: 2

# %%
data = {
    'Subjects' : ['Maths','Physics','Chemistry','English','IT'],
    'Scores' : [95,96,100,97,99]
}
df = pd.DataFrame(data)

plt.figure(figsize = (8,6))
colors = sns.color_palette('husl',len(df))
sns.barplot(x='Subjects',y='Scores',data=df,hue='Subjects',palette=colors,legend=False)

for i,score in enumerate(df['Scores']):
    plt.text(i,score+1,str(score),ha='center',fontsize=12)

plt.grid(axis='y',linestyle='--',alpha=0.7)
plt.title('Score Sheet for  Subjects')
plt.xlabel('Subjects')
plt.ylabel('Scores')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 12
#      10 plt.title(f"Scores for each subject")
#      11 plt.xlabel("subject")
# ---> 12 plt.ylablel("Score")
#      13 plt.grid(True)
#      14 plt.Show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylablel'

# %%
import numpy as np
import matplotlib.pyplot as plt


roll_number = 102317118
np.random.seed(roll_number)


data = np.random.randn(50)

#
fig, axs = plt.subplots(2, 2, figsize=(12, 8))


axs[0, 0].plot(np.cumsum(data), label='Cumulative Sum', color='blue')
axs[0, 0].set_title('Line Plot of Cumulative Sum')
axs[0, 0].set_xlabel('Index')
axs[0, 0].set_ylabel('Cumulative Sum')
axs[0, 0].grid(True)
axs[0, 0].legend()

random_noise = np.random.randn(50)
axs[0, 1].scatter(range(50), random_noise, label='Random Noise', color='red')
axs[0, 1].set_title('Scatter Plot with Random Noise')
axs[0, 1].set_xlabel('Index')
axs[0, 1].set_ylabel('Random Value')
axs[0, 1].grid(True)
axs[0, 1].legend()
ap
fig.tight_layout()


plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


dataset = pd.read_csv("C:\\Users\\chand\\Downloads\\company_sales_data.csv")


plt.figure(figsize=(10,8))
sns.lineplot(data=dataset, x='month_number', y='total_profit', marker='o', color='blue')
plt.title('Total Profit per Month')
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,8))
product_cols = dataset.columns[1:7]
for product in product_cols:
    sns.lineplot(data=dataset,x='month_number',y=product,marker='o',label=product)

plt.title('Product sales per Month')
plt.xlabel('Month number')
plt.ylabel('Sales units')
plt.legend(title='Products')
plt.grid(True)
plt.show()

# %%
data_sum = dataset.sum()
plt.figure(figsize=(14,7))
sns.barplot(x=data_sum.index,y=data_sum.values,palette='viridis')
plt.title('Total Sum of each attribute')
plt.xlabel('Attributes')
plt.ylabel('Total Sum')
plt.xticks(rotation=30)
plt.grid(axis='y',linestyle='--',alpha=0.7)
plt.show()
# Out:
# C:\Users\chand\AppData\Local\Temp\ipykernel_32060\377636605.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data_sum.index,y=data_sum.values,palette='viridis')
